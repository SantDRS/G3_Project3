# %%
# Dependencies
import requests
import json
import pandas as pd
from pprint import pprint

# %%
# retrieve apis, and create jsons

urlRed = 'https://api.sampleapis.com/wines/reds'
urlWhite = 'https://api.sampleapis.com/wines/whites'
urlRose = 'https://api.sampleapis.com/wines/rose'
urlSparkling = 'https://api.sampleapis.com/wines/sparkling'
urlDessert = 'https://api.sampleapis.com/wines/dessert'
urlPort = 'https://api.sampleapis.com/wines/port'

redJson = requests.get(urlRed).json()
whiteJson = requests.get(urlWhite).json()
roseJson = requests.get(urlRose).json()
sparklingJson = requests.get(urlSparkling).json()
dessertJson = requests.get(urlDessert).json()
portJson = requests.get(urlPort).json()

# %%
# convert each json into a dataFrame
reds_df = pd.DataFrame(redJson)
whites_df = pd.DataFrame(whiteJson)
rose_df = pd.DataFrame(roseJson)
sparkling_df = pd.DataFrame(sparklingJson)
dessert_df = pd.DataFrame(dessertJson)
port_df = pd.DataFrame(portJson)

# %%
# check dataframes
reds_df.dtypes
# Out:
# winery      object
# wine        object
# rating      object
# location    object
# image       object
# id           int64
# dtype: object

# %%
# add column 'wine type'
reds_df["wine type"] = 'Red'
whites_df["wine type"] = 'White'
rose_df["wine type"] = 'Rose'
sparkling_df["wine type"] = 'Sparkling'
dessert_df["wine type"] = 'Dessert'
port_df["wine type"] = 'Port'

# %%
# check that columns were added
reds_df
# Out:
#                    winery                                               wine  \
# 0                 Maselva                                       Emporda 2012
# 1           Ernesto Ruffo            Amarone della Valpolicella Riserva N.V.
# 2                 Cartuxa                              Pêra-Manca Tinto 1990
# 3                Schrader  Cabernet Sauvignon RBS Beckstoffer To Kalon Vi...
# 4            Hundred Acre                     Wraith Cabernet Sauvignon 2013
# ..                    ...                                                ...
# 713               Dominus                    Dominus (Christian Moueix) 2013
# 714  Château Cheval Blanc  Saint-Émilion Grand Cru (Premier Grand Cru Cla...
# 715               Masseto                                       Toscana 2011
# 716               Soldera                Brunello di Montalcino Riserva 2005
# 717            Pine Ridge                     Fortis Cabernet Sauvignon N.V.
#
#                                            rating  \
# 0     {'average': '4.9', 'reviews': '88 ratings'}
# 1     {'average': '4.9', 'reviews': '75 ratings'}
# 2     {'average': '4.9', 'reviews': '72 ratings'}
# 3     {'average': '4.9', 'reviews': '72 ratings'}
# 4     {'average': '4.9', 'reviews': '68 ratings'}
# ..                                            ...
# 713  {'average': '4.7', 'reviews': '548 ratings'}
# 714  {'average': '4.7', 'reviews': '546 ratings'}
# 715  {'average': '4.7', 'reviews': '546 ratings'}
# 716  {'average': '4.7', 'reviews': '546 ratings'}
# 717  {'average': '4.7', 'reviews': '546 ratings'}
#
#                                  location  \
# 0                       Spain\n·\nEmpordà
# 1    Italy\n·\nAmarone della Valpolicella
# 2                   Portugal\n·\nAlentejo
# 3              United States\n·\nOakville
# 4           United States\n·\nNapa Valley
# ..                                    ...
# 713         United States\n·\nNapa Valley
# 714    France\n·\nSaint-Émilion Grand Cru
# 715                     Italy\n·\nToscana
# 716      Italy\n·\nBrunello di Montalcino
# 717         United States\n·\nNapa Valley
#
#                                                  image   id wine type
# 0    https://images.vivino.com/thumbs/ApnIiXjcT5Kc3...    1       Red
# 1    https://images.vivino.com/thumbs/nC9V6L2mQQSq0...    2       Red
# 2    https://images.vivino.com/thumbs/L33jsYUuTMWTM...    3       Red
# 3    https://images.vivino.com/thumbs/GpcSXs2ERS6ni...    4       Red
# 4    https://images.vivino.com/thumbs/PBhGMcRNQ7aVn...    5       Red
# ..                                                 ...  ...       ...
# 713  https://images.vivino.com/thumbs/FvLdztxrRXOZx...  714       Red
# 714  https://images.vivino.com/thumbs/AIWJqsLoSIyz0...  715       Red
# 715  https://images.vivino.com/thumbs/GPvEr_IUSKS1C...  716       Red
# 716  https://images.vivino.com/thumbs/l_eXmV1KTdGzz...  717       Red
# 717  https://images.vivino.com/thumbs/nu85uiOyQiay0...  718       Red
#
# [718 rows x 7 columns]

# %%
# create new id keys
reds_df['id'] = ['r'+ '{:0>4}'.format(str(id)) for id in reds_df['id']]
whites_df['id'] = ['w'+ '{:0>4}'.format(str(id)) for id in whites_df['id']]
rose_df['id'] = ['o'+ '{:0>4}'.format(str(id)) for id in rose_df['id']]
sparkling_df['id'] = ['s'+ '{:0>4}'.format(str(id)) for id in sparkling_df['id']]
dessert_df['id'] = ['d'+ '{:0>4}'.format(str(id)) for id in dessert_df['id']]
port_df['id'] = ['p'+ '{:0>4}'.format(str(id)) for id in port_df['id']]

# %%
# check dataframes
whites_df
# Out:
#                                    winery  \
# 0             Domaine de La Romanée-Conti
# 1             Domaine de La Romanée-Conti
# 2                      Domaine Coche-Dury
# 3                      Domaine Coche-Dury
# 4                                  Jarvis
# ..                                    ...
# 499                      Domaine Leflaive
# 500                  Château de Meursault
# 501  Domaine d'Auvenay (Lalou Bize Leroy)
# 502                              Penfolds
# 503               Pierre-Yves Colin-Morey
#
#                                                   wine  \
# 0                            Montrachet Grand Cru 2010
# 1                            Montrachet Grand Cru 2014
# 2                          Meursault Les Rougeots 2001
# 3                    Corton-Charlemagne Grand Cru N.V.
# 4    Estate Finch Hollow Chardonnay (Cave Fermented...
# ..                                                 ...
# 499                Chevalier-Montrachet Grand Cru 2015
# 500        Puligny-Montrachet 1er Cru Champ Canet 2011
# 501                                Auxey-Duresses 2004
# 502                 Yattarna Chardonnay (BIN 144) 2003
# 503  Chassagne-Montrachet Premier Cru Abbaye de Mor...
#
#                                            rating  \
# 0     {'average': '4.9', 'reviews': '37 ratings'}
# 1     {'average': '4.9', 'reviews': '33 ratings'}
# 2     {'average': '4.9', 'reviews': '25 ratings'}
# 3    {'average': '4.8', 'reviews': '416 ratings'}
# 4    {'average': '4.8', 'reviews': '113 ratings'}
# ..                                            ...
# 499   {'average': '4.6', 'reviews': '27 ratings'}
# 500   {'average': '4.6', 'reviews': '27 ratings'}
# 501   {'average': '4.6', 'reviews': '27 ratings'}
# 502   {'average': '4.6', 'reviews': '27 ratings'}
# 503   {'average': '4.6', 'reviews': '27 ratings'}
#
#                                               location  \
# 0                      France\n·\nMontrachet Grand Cru
# 1                      France\n·\nMontrachet Grand Cru
# 2                                 France\n·\nMeursault
# 3              France\n·\nCorton-Charlemagne Grand Cru
# 4                        United States\n·\nNapa Valley
# ..                                                 ...
# 499          France\n·\nChevalier-Montrachet Grand Cru
# 500          France\n·\nPuligny-Montrachet Premier Cru
# 501                          France\n·\nAuxey-Duresses
# 502                       Australia\n·\nAdelaide Hills
# 503  France\n·\nChassagne-Montrachet 1er Cru 'Abbay...
#
#                                                  image     id wine type
# 0    https://images.vivino.com/thumbs/rORmihtxSrKG7...  w0001     White
# 1    https://images.vivino.com/thumbs/rORmihtxSrKG7...  w0002     White
# 2    https://images.vivino.com/thumbs/l5W5NRvZR_SzC...  w0003     White
# 3    https://images.vivino.com/thumbs/ZGxHdQyGQt-hf...  w0004     White
# 4    https://images.vivino.com/thumbs/pQ_92smWRKG7Y...  w0005     White
# ..                                                 ...    ...       ...
# 499  https://images.vivino.com/thumbs/lD32nuv9Sw6sJ...  w0500     White
# 500  https://images.vivino.com/thumbs/cDjOBVU0QW-ur...  w0501     White
# 501  https://images.vivino.com/thumbs/OzI_mGYSQdCoy...  w0502     White
# 502  https://images.vivino.com/thumbs/aMdgLSKeQVybJ...  w0503     White
# 503  https://images.vivino.com/thumbs/lj7yTJRLQoWN2...  w0504     White
#
# [504 rows x 7 columns]

# %%
# concatenate dataframes
wine_dataframes = [reds_df,whites_df,rose_df,sparkling_df,dessert_df,port_df]
wine_df = pd.concat(wine_dataframes)

# %%
# check combined wine_df
wine_df
# Out:
#                 winery                                               wine  \
# 0              Maselva                                       Emporda 2012
# 1        Ernesto Ruffo            Amarone della Valpolicella Riserva N.V.
# 2              Cartuxa                              Pêra-Manca Tinto 1990
# 3             Schrader  Cabernet Sauvignon RBS Beckstoffer To Kalon Vi...
# 4         Hundred Acre                     Wraith Cabernet Sauvignon 2013
# ..                 ...                                                ...
# 398        Toro Albalá                           Don PX Gran Reserva 1986
# 399  Quinta do Vallado                      Porto 20 Years Old Tawny N.V.
# 400    Quinta do Noval                                  Vintage Port N.V.
# 401       Royal Oporto                       20 Year Old Tawny Porto N.V.
# 402       Royal Oporto                                Colheita Porto N.V.
#
#                                             rating  \
# 0      {'average': '4.9', 'reviews': '88 ratings'}
# 1      {'average': '4.9', 'reviews': '75 ratings'}
# 2      {'average': '4.9', 'reviews': '72 ratings'}
# 3      {'average': '4.9', 'reviews': '72 ratings'}
# 4      {'average': '4.9', 'reviews': '68 ratings'}
# ..                                             ...
# 398  {'average': '4.4', 'reviews': '1077 ratings'}
# 399  {'average': '4.4', 'reviews': '1035 ratings'}
# 400  {'average': '4.4', 'reviews': '1018 ratings'}
# 401   {'average': '4.4', 'reviews': '898 ratings'}
# 402   {'average': '4.4', 'reviews': '881 ratings'}
#
#                                  location  \
# 0                       Spain\n·\nEmpordà
# 1    Italy\n·\nAmarone della Valpolicella
# 2                   Portugal\n·\nAlentejo
# 3              United States\n·\nOakville
# 4           United States\n·\nNapa Valley
# ..                                    ...
# 398            Spain\n·\nMontilla-Moriles
# 399                    Portugal\n·\nPorto
# 400             Portugal\n·\nVintage Port
# 401          Portugal\n·\nAged Tawny Port
# 402            Portugal\n·\nColheita Port
#
#                                                  image     id wine type
# 0    https://images.vivino.com/thumbs/ApnIiXjcT5Kc3...  r0001       Red
# 1    https://images.vivino.com/thumbs/nC9V6L2mQQSq0...  r0002       Red
# 2    https://images.vivino.com/thumbs/L33jsYUuTMWTM...  r0003       Red
# 3    https://images.vivino.com/thumbs/GpcSXs2ERS6ni...  r0004       Red
# 4    https://images.vivino.com/thumbs/PBhGMcRNQ7aVn...  r0005       Red
# ..                                                 ...    ...       ...
# 398  https://images.vivino.com/thumbs/qAad7NzITH-si...  p0399      Port
# 399  https://images.vivino.com/thumbs/jHGhovW_QZ6b4...  p0400      Port
# 400  https://images.vivino.com/thumbs/y9P75uaVT6yoG...  p0401      Port
# 401  https://images.vivino.com/thumbs/4usgrqCrTUKag...  p0402      Port
# 402  https://images.vivino.com/thumbs/QnSyShsLRguoG...  p0403      Port
#
# [3455 rows x 7 columns]

# %%
wine_df = wine_df.set_index('id')

# %%
# split location into 'country' and 'region'
wine_df[['country','region']] = wine_df.location.str.split('\\n·\\n', expand=True)

# %%
# checking dataframe
wine_df
# Out:
#                   winery                                               wine  \
# id
# r0001            Maselva                                       Emporda 2012
# r0002      Ernesto Ruffo            Amarone della Valpolicella Riserva N.V.
# r0003            Cartuxa                              Pêra-Manca Tinto 1990
# r0004           Schrader  Cabernet Sauvignon RBS Beckstoffer To Kalon Vi...
# r0005       Hundred Acre                     Wraith Cabernet Sauvignon 2013
# ...                  ...                                                ...
# p0399        Toro Albalá                           Don PX Gran Reserva 1986
# p0400  Quinta do Vallado                      Porto 20 Years Old Tawny N.V.
# p0401    Quinta do Noval                                  Vintage Port N.V.
# p0402       Royal Oporto                       20 Year Old Tawny Porto N.V.
# p0403       Royal Oporto                                Colheita Porto N.V.
#
#                                               rating  \
# id
# r0001    {'average': '4.9', 'reviews': '88 ratings'}
# r0002    {'average': '4.9', 'reviews': '75 ratings'}
# r0003    {'average': '4.9', 'reviews': '72 ratings'}
# r0004    {'average': '4.9', 'reviews': '72 ratings'}
# r0005    {'average': '4.9', 'reviews': '68 ratings'}
# ...                                              ...
# p0399  {'average': '4.4', 'reviews': '1077 ratings'}
# p0400  {'average': '4.4', 'reviews': '1035 ratings'}
# p0401  {'average': '4.4', 'reviews': '1018 ratings'}
# p0402   {'average': '4.4', 'reviews': '898 ratings'}
# p0403   {'average': '4.4', 'reviews': '881 ratings'}
#
#                                    location  \
# id
# r0001                     Spain\n·\nEmpordà
# r0002  Italy\n·\nAmarone della Valpolicella
# r0003                 Portugal\n·\nAlentejo
# r0004            United States\n·\nOakville
# r0005         United States\n·\nNapa Valley
# ...                                     ...
# p0399            Spain\n·\nMontilla-Moriles
# p0400                    Portugal\n·\nPorto
# p0401             Portugal\n·\nVintage Port
# p0402          Portugal\n·\nAged Tawny Port
# p0403            Portugal\n·\nColheita Port
#
#                                                    image wine type  \
# id
# r0001  https://images.vivino.com/thumbs/ApnIiXjcT5Kc3...       Red
# r0002  https://images.vivino.com/thumbs/nC9V6L2mQQSq0...       Red
# r0003  https://images.vivino.com/thumbs/L33jsYUuTMWTM...       Red
# r0004  https://images.vivino.com/thumbs/GpcSXs2ERS6ni...       Red
# r0005  https://images.vivino.com/thumbs/PBhGMcRNQ7aVn...       Red
# ...                                                  ...       ...
# p0399  https://images.vivino.com/thumbs/qAad7NzITH-si...      Port
# p0400  https://images.vivino.com/thumbs/jHGhovW_QZ6b4...      Port
# p0401  https://images.vivino.com/thumbs/y9P75uaVT6yoG...      Port
# p0402  https://images.vivino.com/thumbs/4usgrqCrTUKag...      Port
# p0403  https://images.vivino.com/thumbs/QnSyShsLRguoG...      Port
#
#              country                      region
# id
# r0001          Spain                     Empordà
# r0002          Italy  Amarone della Valpolicella
# r0003       Portugal                    Alentejo
# r0004  United States                    Oakville
# r0005  United States                 Napa Valley
# ...              ...                         ...
# p0399          Spain            Montilla-Moriles
# p0400       Portugal                       Porto
# p0401       Portugal                Vintage Port
# p0402       Portugal             Aged Tawny Port
# p0403       Portugal               Colheita Port
#
# [3455 rows x 8 columns]

# %%
# split rating into 'average rating' and 'review count'
#print(type(wine_df.iloc[0]['rating']))
averageRating = []
reviewCount = []

for index, wine in wine_df.iterrows():
    avg = wine['rating']['average']
    rev = wine['rating']['reviews']
    averageRating.append(float(avg))
    reviewCount.append(int(rev[:2]))

# %%
# adding 'average rating' and 'review count' columns
wine_df['average rating'] = averageRating
wine_df['review count'] = reviewCount

# %%
# checking dataframe
wine_df
# Out:
#                   winery                                               wine  \
# id
# r0001            Maselva                                       Emporda 2012
# r0002      Ernesto Ruffo            Amarone della Valpolicella Riserva N.V.
# r0003            Cartuxa                              Pêra-Manca Tinto 1990
# r0004           Schrader  Cabernet Sauvignon RBS Beckstoffer To Kalon Vi...
# r0005       Hundred Acre                     Wraith Cabernet Sauvignon 2013
# ...                  ...                                                ...
# p0399        Toro Albalá                           Don PX Gran Reserva 1986
# p0400  Quinta do Vallado                      Porto 20 Years Old Tawny N.V.
# p0401    Quinta do Noval                                  Vintage Port N.V.
# p0402       Royal Oporto                       20 Year Old Tawny Porto N.V.
# p0403       Royal Oporto                                Colheita Porto N.V.
#
#                                               rating  \
# id
# r0001    {'average': '4.9', 'reviews': '88 ratings'}
# r0002    {'average': '4.9', 'reviews': '75 ratings'}
# r0003    {'average': '4.9', 'reviews': '72 ratings'}
# r0004    {'average': '4.9', 'reviews': '72 ratings'}
# r0005    {'average': '4.9', 'reviews': '68 ratings'}
# ...                                              ...
# p0399  {'average': '4.4', 'reviews': '1077 ratings'}
# p0400  {'average': '4.4', 'reviews': '1035 ratings'}
# p0401  {'average': '4.4', 'reviews': '1018 ratings'}
# p0402   {'average': '4.4', 'reviews': '898 ratings'}
# p0403   {'average': '4.4', 'reviews': '881 ratings'}
#
#                                    location  \
# id
# r0001                     Spain\n·\nEmpordà
# r0002  Italy\n·\nAmarone della Valpolicella
# r0003                 Portugal\n·\nAlentejo
# r0004            United States\n·\nOakville
# r0005         United States\n·\nNapa Valley
# ...                                     ...
# p0399            Spain\n·\nMontilla-Moriles
# p0400                    Portugal\n·\nPorto
# p0401             Portugal\n·\nVintage Port
# p0402          Portugal\n·\nAged Tawny Port
# p0403            Portugal\n·\nColheita Port
#
#                                                    image wine type  \
# id
# r0001  https://images.vivino.com/thumbs/ApnIiXjcT5Kc3...       Red
# r0002  https://images.vivino.com/thumbs/nC9V6L2mQQSq0...       Red
# r0003  https://images.vivino.com/thumbs/L33jsYUuTMWTM...       Red
# r0004  https://images.vivino.com/thumbs/GpcSXs2ERS6ni...       Red
# r0005  https://images.vivino.com/thumbs/PBhGMcRNQ7aVn...       Red
# ...                                                  ...       ...
# p0399  https://images.vivino.com/thumbs/qAad7NzITH-si...      Port
# p0400  https://images.vivino.com/thumbs/jHGhovW_QZ6b4...      Port
# p0401  https://images.vivino.com/thumbs/y9P75uaVT6yoG...      Port
# p0402  https://images.vivino.com/thumbs/4usgrqCrTUKag...      Port
# p0403  https://images.vivino.com/thumbs/QnSyShsLRguoG...      Port
#
#              country                      region  average rating  review count
# id
# r0001          Spain                     Empordà             4.9            88
# r0002          Italy  Amarone della Valpolicella             4.9            75
# r0003       Portugal                    Alentejo             4.9            72
# r0004  United States                    Oakville             4.9            72
# r0005  United States                 Napa Valley             4.9            68
# ...              ...                         ...             ...           ...
# p0399          Spain            Montilla-Moriles             4.4            10
# p0400       Portugal                       Porto             4.4            10
# p0401       Portugal                Vintage Port             4.4            10
# p0402       Portugal             Aged Tawny Port             4.4            89
# p0403       Portugal               Colheita Port             4.4            88
#
# [3455 rows x 10 columns]

# %%
# removing 'rating' and 'location' columns
del wine_df['rating']
del wine_df['location']

# %%
# checking dataframe
wine_df
# Out:
#                   winery                                               wine  \
# id
# r0001            Maselva                                       Emporda 2012
# r0002      Ernesto Ruffo            Amarone della Valpolicella Riserva N.V.
# r0003            Cartuxa                              Pêra-Manca Tinto 1990
# r0004           Schrader  Cabernet Sauvignon RBS Beckstoffer To Kalon Vi...
# r0005       Hundred Acre                     Wraith Cabernet Sauvignon 2013
# ...                  ...                                                ...
# p0399        Toro Albalá                           Don PX Gran Reserva 1986
# p0400  Quinta do Vallado                      Porto 20 Years Old Tawny N.V.
# p0401    Quinta do Noval                                  Vintage Port N.V.
# p0402       Royal Oporto                       20 Year Old Tawny Porto N.V.
# p0403       Royal Oporto                                Colheita Porto N.V.
#
#                                                    image wine type  \
# id
# r0001  https://images.vivino.com/thumbs/ApnIiXjcT5Kc3...       Red
# r0002  https://images.vivino.com/thumbs/nC9V6L2mQQSq0...       Red
# r0003  https://images.vivino.com/thumbs/L33jsYUuTMWTM...       Red
# r0004  https://images.vivino.com/thumbs/GpcSXs2ERS6ni...       Red
# r0005  https://images.vivino.com/thumbs/PBhGMcRNQ7aVn...       Red
# ...                                                  ...       ...
# p0399  https://images.vivino.com/thumbs/qAad7NzITH-si...      Port
# p0400  https://images.vivino.com/thumbs/jHGhovW_QZ6b4...      Port
# p0401  https://images.vivino.com/thumbs/y9P75uaVT6yoG...      Port
# p0402  https://images.vivino.com/thumbs/4usgrqCrTUKag...      Port
# p0403  https://images.vivino.com/thumbs/QnSyShsLRguoG...      Port
#
#              country                      region  average rating  review count
# id
# r0001          Spain                     Empordà             4.9            88
# r0002          Italy  Amarone della Valpolicella             4.9            75
# r0003       Portugal                    Alentejo             4.9            72
# r0004  United States                    Oakville             4.9            72
# r0005  United States                 Napa Valley             4.9            68
# ...              ...                         ...             ...           ...
# p0399          Spain            Montilla-Moriles             4.4            10
# p0400       Portugal                       Porto             4.4            10
# p0401       Portugal                Vintage Port             4.4            10
# p0402       Portugal             Aged Tawny Port             4.4            89
# p0403       Portugal               Colheita Port             4.4            88
#
# [3455 rows x 8 columns]

# %%
# getting a list of the unique wineries in the dataframe
wineryList = wine_df['winery'].unique()
wineryList
# Out:
# array(['Maselva', 'Ernesto Ruffo', 'Cartuxa', ..., 'Quinta de S. José',
#        'Alves de Sousa', 'Wine & Soul'], dtype=object)

# %%
#getting a list of the unique countries in the dataframe
countryList = wine_df['country'].unique()
countryList
# Out:
# array(['Spain', 'Italy', 'Portugal', 'United States', 'France', '',
#        'Argentina', 'South Africa', 'Hungary', 'Australia', 'Chile',
#        'Austria', 'Macedonia', 'Canada', 'Germany', 'Romania',
#        'Switzerland', 'New Zealand', 'Slovenia', 'Georgia', 'Greece',
#        'Israel', 'Turkey', 'Moldova', 'Brazil', 'Uruguay'], dtype=object)

# %%
#getting a list of the unique regions in the dataframe
regionList = wine_df['region'].unique()
regionList
# Out:
# array(['Empordà', 'Amarone della Valpolicella', 'Alentejo', 'Oakville',
#        'Napa Valley', 'California', 'Rutherford', 'Veneto', 'Côte-Rôtie',
#        None, 'Chambertin Grand Cru', 'Agrelo', 'Ribera del Duero',
#        'Moon Mountain District', 'Barolo', 'Stellenbosch',
#        'Diamond Mountain District', 'Western Cape', 'Szekszárd',
#        'Howell Mountain', 'Musigny Grand Cru', 'Toro', 'Sta. Rita Hills',
#        'St. Helena', 'Russian River Valley',
#        'Romanée-Saint-Vivant Grand Cru', 'Heathcote', 'Haut-Médoc',
#        'Amarone della Valpolicella Classico', 'Échezeaux Grand Cru',
#        'McLaren Vale', 'Vosne-Romanée Premier Cru', 'Yamhill County',
#        'Fleurieu', 'Pomerol', 'Sonoma Mountain', 'Madeira',
#        'Barossa Valley', 'Douro', 'Pauillac', 'Mendoza', 'Margaux',
#        'Toscana', 'Perdriel', 'Saint-Émilion Grand Cru',
#        'Bolgheri Sassicaia', 'La Tâche Grand Cru', 'Tunuyán',
#        'South Australia', 'Colchagua Valley', 'Mount Veeder',
#        'Uco Valley', 'Stags Leap District', 'Niederösterreich',
#        'Grands-Échezeaux Grand Cru', 'Richebourg Grand Cru',
#        'Romanée-Conti Grand Cru', 'Langhe', 'Champagne', 'Povardarie',
#        'Eden Valley', 'Châteauneuf-du-Pape', 'Saint-Émilion',
#        'Santa Barbara County', 'Rioja', 'Sonoma Valley',
#        'Brunello di Montalcino', 'Central Coast', 'Santa Lucia Highlands',
#        'Knights Valley', 'Chambertin-Clos de Bèze Grand Cru', 'Priorat',
#        'Maremma Toscana', 'Jumilla', 'Côte de Nuits', 'Dry Creek Valley',
#        'Paso Robles', 'Bonnes-Mares Grand Cru',
#        'Clos de la Roche Grand Cru', 'Edna Valley', 'Sonoma Coast',
#        'Spring Mountain District', 'Hermitage', 'Walla Walla Valley',
#        'Pessac-Léognan', 'La Clape', 'Saint-Julien', 'Maipo Valley',
#        'Hérault', 'Vosne-Romanée', 'Salento', 'Primitivo di Manduria',
#        'Corton Grand Cru', 'La Romanée Grand Cru', 'Okanagan Valley',
#        'Calistoga', 'Coombsville', 'Oak Knoll District', 'Barbaresco',
#        'Cádiz', 'Borba', 'Sardegna',
#        "Chambolle-Musigny 1er Cru 'Les Amoureuses'", 'Anderson Valley',
#        'Puente Alto', 'Bolgheri Superiore', 'Saint-Estèphe', 'Alentejano',
#        'Montrachet Grand Cru', 'Meursault',
#        'Corton-Charlemagne Grand Cru', 'Bordeaux Supérieur',
#        'Bâtard-Montrachet Grand Cru', 'Alsace', 'Rheinhessen', 'Wachau',
#        'Chevalier-Montrachet Grand Cru', "Chablis 1er Cru 'Butteaux'",
#        'Meursault Premier Cru', 'Valdeorras', 'Pouilly-Fumé',
#        'Puligny-Montrachet Premier Cru', 'Pouilly-Fuissé', 'Wehlen',
#        'Wiltingen', 'Sonoma County', 'Pfalz', 'Kamptal',
#        'Puligny-Montrachet', "Chablis Grand Cru 'Blanchot'", 'Bordeaux',
#        "Chassagne-Montrachet 1er Cru 'Cailleret'", 'Los Carneros',
#        "Chablis Grand Cru 'Les Clos'", "Chablis Grand Cru 'Valmur'",
#        'Franschhoek', 'Rías Baixas', 'Wagram',
#        "Meursault 1er Cru 'Charmes'", 'Rivesaltes',
#        'Bienvenues-Bâtard-Montrachet Grand Cru', 'Condrieu',
#        'Criots-Bâtard-Montrachet Grand Cru',
#        "Chassagne-Montrachet 1er Cru 'Les Vergers'",
#        "Chablis Grand Cru 'Preuses'", 'Evora', 'Recas', 'Swartland',
#        'Marche', 'Dundee Hills', 'Overberg', 'Südtirol - Alto Adige',
#        'Saumur', 'Beechworth', 'Margaret River', 'Mosel',
#        "Beaune 1er Cru 'Le Clos des Mouches'", 'Lugana',
#        "Meursault 1er Cru 'Les Bouchères'",
#        "Meursault 1er Cru 'Perrières'", 'Venezia',
#        "Chassagne-Montrachet 1er Cru 'Morgeot'", 'Graubünden', 'Cognac',
#        'Piemonte', "Chassagne-Montrachet 1er Cru 'Les Grandes Ruchottes'",
#        'Alsace Grand Cru', 'Trentino-Alto Adige', 'Sancerre',
#        'Bonnezeaux', 'Waiheke Island', 'Chassagne-Montrachet Premier Cru',
#        'Ribeiro', "Meursault 1er Cru 'Genevrières'",
#        'Santa Cruz Mountains', 'Rogue Valley', 'Mittelrhein',
#        'Château-Grillet', 'Málaga', 'Ticino',
#        "Puligny-Montrachet 1er Cru 'La Truffière'",
#        "Meursault 1er Cru 'La pièce sous le Bois'", 'Isola dei Nuraghi',
#        "Vougeot 1er Cru 'Le Clos Blanc'", 'Nahe',
#        'Colli Orientali del Friuli', 'Andalucía', 'Vouvray', 'Baden',
#        'Chamoson', 'delle Venezie', 'Côtes-du-Rhône', 'Elgin',
#        'Vins des Allobroges', "Chablis Grand Cru 'Vaudesir'",
#        'Auxey-Duresses', 'Adelaide Hills',
#        "Chassagne-Montrachet 1er Cru 'Abbaye de Morgeot'",
#        'Willamette Valley', "Vino d'Italia", 'Provence',
#        'Côtes de Provence', 'Palette', 'Bandol', 'Languedoc', 'Lazio',
#        'Valpolicella', "Malvasia di Casorzo d'Asti", 'Vipava',
#        'Mendocino County', 'Kakheti', 'Vin de France', 'Vinho Verde',
#        'Pennsylvania', 'Corbières', 'Península de Setúbal',
#        'Malvasia di Castelnuovo don Bosco', "Rosé d'Anjou", 'Lake County',
#        'Catalunya', 'Achaia', 'Rioja Alta', "Coteaux d'Aix-en-Provence",
#        'Paestum', 'Setúbal', 'Coste della Sesia', 'Getariako Txakolina',
#        'Weinland', 'Jerusalem', "Cerasuolo d'Abruzzo",
#        'Coteaux Varois en Provence', 'Yamhill-Carlton District',
#        'Corsica', 'Coastal Region', 'Venezia Giulia',
#        'Bizkaiko Txakolina', 'Štajerska', 'Upper Loire', 'Rheingau',
#        'Gigondas', 'El Dorado', 'Neusiedlersee-Hügelland', 'Burgenland',
#        'Ardèche', 'Terre Siciliane', 'Fthiotida', 'Bairrada', 'Valencia',
#        'Marlborough', 'Happy Canyon of Santa Barbara', 'Victoria',
#        'Indiana', 'Chehalem Mountains', 'Tavel', 'Costières-de-Nîmes',
#        'Colline Novaresi', 'Vigneti delle Dolomiti', 'Emilia-Romagna',
#        'Côtes du Roussillon', 'Vallagarina', 'Cassis', 'Central Otago',
#        'Luberon', 'Finger Lakes', 'Chablais', 'Oregon', 'Vaucluse',
#        'South Eastern Australia', 'Long Island', 'Ile de Beaute',
#        'Benaco Bresciano', 'Chinon', 'San Luis Obispo County', 'Umbria',
#        "Costa d'Amalfi", 'Blaye - Côtes de Bordeaux', 'Beaujolais',
#        'Terratico di Bibbona', 'Bellet', 'Drôme', 'Saint-Drézéry',
#        'Vallee du Paradis', 'Navarra', 'Clear Lake', 'Patrimonio',
#        'Alexander Valley', 'Columbia Valley', 'Mallorca', 'Aude',
#        'Steiermark', 'Côtes de Gascogne', 'Clare Valley', 'Algarve',
#        'Languedoc-Roussillon', 'Lake Erie New York', 'Rhone Valley',
#        'Garda', 'Denizli', 'North Coast', "Cabernet d'Anjou",
#        'Arroyo Seco', 'Mornington Peninsula', 'South Eastern',
#        'Champagne Premier Cru', "Champagne Grand Cru 'Ambonnay'",
#        'Conegliano-Valdobbiadene Prosecco Superiore',
#        'Champagne Grand Cru', "Champagne Grand Cru 'Avize'",
#        "Champagne Grand Cru 'Aÿ'", 'Trento', 'Cava', 'Franciacorta',
#        "Champagne Grand Cru 'Le Mesnil-sur-Oger'", 'Coteaux Champenois',
#        'Serra Gaúcha', "Moscato d'Asti", 'Soave', 'Provincia di Pavia',
#        'Conegliano-Valdobbiadene Prosecco',
#        "Champagne Grand Cru 'Cramant'", 'Vale dos Vinhedos', 'Trentino',
#        'Gavi', "Brachetto d'Acqui", "Champagne Grand Cru 'Oger'",
#        'Recioto della Valpolicella', 'Niagara Peninsula', 'Tokaj',
#        'Arbois', 'Sauternes', 'Vin Santo di Montepulciano', 'Santorini',
#        'Carmignano', 'Montefalco Sagrantino', 'Passito di Pantelleria',
#        'Montecarlo', 'Vin Santo del Chianti Classico', 'Constantia',
#        'Barsac', 'Jurançon', 'Quarts de Chaume', 'Rutherglen',
#        "Alsace Grand Cru 'Rangen'", 'Calabria', 'Friuli-Venezia Giulia',
#        "Alsace Grand Cru 'Altenberg de Bergheim'", 'Atlàntida',
#        'Vin Santo del Chianti', 'Recioto della Valpolicella Classico',
#        'Monbazillac', 'Albana di Romagna', 'Racha-Lechkhumi',
#        'Neusiedlersee', 'Maule Valley', 'Pineau des Charentes',
#        'Orvieto Classico', 'Moscato di Scanzo', 'Cinque Terre', 'Palmela',
#        'Marsala', 'Montlouis-sur-Loire', 'Brauneberg', 'Chianti',
#        'Vin Santo di Carmignano', 'Malvasia delle Lipari', 'Vin Santo',
#        'Paarl', 'Breganze', 'Liguria', 'Virginia', 'Weinviertel',
#        'Yakima Valley', 'Terrazze Retiche di Sondrio',
#        "Vin Santo Sant'Antimo", 'Fully', 'Vintage Port',
#        'Montilla-Moriles', 'Pedro Ximénez Sherry (PX)', 'Colheita Port',
#        'Tawny Port', 'Jerez-Xérès-Sherry', 'Aged Tawny Port',
#        'Palo Cortado Sherry', 'Single Quinta Vintage Port (SQVP)',
#        'Late Bottled Vintage Port (LBV)', 'Porto', 'Reserve Port',
#        'Amontillado Sherry', 'Muscat de Rivesaltes', 'Oloroso Sherry',
#        'Barossa', 'Banyuls Grand Cru'], dtype=object)

# %%
# getting a list of the wine types
wineTypeList = wine_df['wine type'].unique()
wineTypeList
# Out:
# array(['Red', 'White', 'Rose', 'Sparkling', 'Dessert', 'Port'],
#       dtype=object)
